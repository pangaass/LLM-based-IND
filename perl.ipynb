# %%
import json

with open('res.json', 'r') as f:
    metric = json.load(f)

with open('resl.json', 'r') as f:
    author  = json.load(f)
res = []
for m,a in zip(metric, author):
    res.append((str(m)+a))

# %%
res
# Out:
# ['[0.9428571428571428, 0.9689119170984456, 0.9970163591793744, 0.9648840206185567]MJUuLRh2',
#  '[0.9139784946236559, 0.9550561797752809, 0.9365024416832449, 0.5038314176245211]ecAXeq2g',
#  '[0.9375, 0.96, 0.9856275344792507, 0.9542857142857144]FDHfvfW5',
#  '[0.9817850637522769, 0.9907578558225508, 0.9959482149853184, 0.7915899324739104]4V01z3bP',
#  '[0.9384615384615385, 0.9682539682539683, 0.9776351135206722, 0.6967213114754098]uPofywtY',
#  '[0.7746478873239436, 0.873015873015873, 0.6146895316467331, 0.09880952380952382]NhpKeTsv',
#  '[0.9825174825174825, 0.9909584086799277, 0.9999999999999999, 1.0]qCfyWN8p',
#  '[0.8837209302325582, 0.888888888888889, 0.9447784350116005, 0.9232456140350878]SuDLeq8N',
#  '[0.6521739130434783, 0.33333333333333337, 0.3215038153968155, 0.5766233766233766]9hUQY912',
#  '[0.967741935483871, 0.9833333333333334, 0.9946173258417399, 0.8940924395469849]H5BPpDqU',
#  '[1.0, 1.0, 1.0, 1.0]uWjvRBUn',
# ...
